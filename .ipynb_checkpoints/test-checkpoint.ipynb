# %%
import glob
import h5py
import itertools
import matplotlib.pyplot as plt
import numpy as np
from sklearn.preprocessing import normalize

''' Load dataset '''
trainPath = './dataset/SeqTrain/'
valPath = './dataset/SeqVal/'


trainFile = glob.glob(trainPath + '*.h5')
valFile = glob.glob(valPath + '*.h5')

data = h5py.File(trainFile[1], 'r')

# %%
# for i in range(1,199):
# #     print('index', i)
# #     print('speed: ',data['targets'][i][10])
#     diff = np.subtract(data['rgb'][i], data['rgb'][i+1])
# #     print('norm: ', np.sqrt(np.sum(diff**2)))
# #     plt.imshow(diff)
#     plt.imsave('look/1{}.png'.format(i), diff)
# #     plt.show()

# %%
diff = np.subtract(data['rgb'][1], data['rgb'][2])

# %%
plt.figure(figsize=(20,10))
fig, ax = plt.subplots()
fig2, ax2 = plt.subplots()
x = np.arange(199)
speed = []
norm = []

for i in range(0, 199):
    speed.append(data['targets'][i][10])
    norm.append(np.sqrt(np.sum((np.subtract(data['rgb'][i+1], data['rgb'][i])**2))))


for p in range(len(data['targets'])):
    ax.plot(x, speed)
    ax2.plot(x, norm)
    

    
plt.show()

# %%
fig = plt.figure()
ax = plt.axes()

a = np.arange(201)
# ax.plot(x, np.sin(x));
a
